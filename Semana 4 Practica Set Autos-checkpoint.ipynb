# %% [markdown]
# <center> <img SRC="coche.jpg" aling="center"/> </center>
# <center> <h1 style="color:#800000"> Analisis sobre venta de vehiculos </h1> </center>
# <center> <h2 style="color:#800000"> Curso de visualizacion de datos </h2> </center>
# <center> <h3 style="color:#800000"> III C-2021 </h3> </center>
#
# <p style="text-aling:justify"> Este es un analisis para poder identificar las caracteristicas de los autos que se venden y sua precios.
#     Para posterior trabajar un documento formal con las conclusiones obtenidos producto de la visualizacion de datos que se desarrollará en el presente trabajo, esto como parte de transitar del curso de analisis de datos de la Universidad Castro Carazo. </p>

# %% [markdown]
# <h2 style="color:#2F4F4F">1.Carga y estandarizacion de los archivos de datos </h2>
# <p> Que se hace en este apartado? </p>
# <ol>
#     <li>Importar las librerias que se necesitan</li>
#     <li>Importar los set de datos de los CSV</li>
#     <li>Revisar los enmcabezados de los Dataframes</li>
#     <li>Unir los marcos de los datos(DataFrames)</li>
# </ol>
# <h3 style="color:#483d8b">1.1 Importacion de librerias</h3>

# %%
# Se realiza la importacion de las librerias necesarias para el Analisis de Datos.
import pandas as pd # El manejo de los marcos de datos (Dataframes)
import numpy as np #El manejo de estructuras de datos cmo listas, directorios,arrays.
import matplotlib.pyplot as plt # Se utiliza para crear graficas basadas en los datos.
import matplotlib as mplt # Se utliza para crear basicas basadas en datos.

# %% [markdown]
# <h3 style="color:#483d8b">1.2 Carga de Datos</h3>

# %%
#Se crea 
cols = ["simbolizando", "perdidasNormalizadas", "marca", "tipoCombustible", "aspiracion", "numPuertas", "estiloCarroceria",
"ruedasMotrices", "ubicacionMotor", "baseRuedas", "longitud", "ancho", "altura", "peso", "tipoMotor", "numCilindros",
"tamanoMotor", "sistemaCombustible", "diametro", "kilometraje", "relacionCompresion", "caballosFuerza", "rpmPico",
"mpgCiduad", "mpgAutopista", "precio"]

#Carga del set de datos.
dfAutos1=pd.read_csv("autos.csv",names=cols)
dfAutos2=pd.read_csv("autos2.csv",names=cols)

# %%
dfAutos1.shape #Cuantas filas y columnas forman el set de datos
# Out:
# (99, 26)

# %%
dfAutos2.shape
# Out:
# (98, 26)

# %%
dfAutos1.head(10) # Sirve para verificar los primeros 10 datos
# Out:
#    simbolizando perdidasNormalizadas        marca tipoCombustible aspiracion  \
# 0             3                    ?  alfa-romero             gas        std
# 1             3                    ?  alfa-romero             gas        std
# 2             1                    ?  alfa-romero             gas        std
# 3             2                  164         audi             gas        std
# 4             2                  164         audi             gas        std
# 5             2                    ?         audi             gas        std
# 6             1                  158         audi             gas        std
# 7             1                    ?         audi             gas        std
# 8             1                  158         audi             gas      turbo
# 9             0                    ?         audi             gas      turbo
#
#   numPuertas estiloCarroceria ruedasMotrices ubicacionMotor  baseRuedas  ...  \
# ...

# %%
dfAutos1.tail(10) # Sirve para verificar las ultimas 10 filas
# Out:
#     simbolizando perdidasNormalizadas   marca tipoCombustible aspiracion  \
# 89             1                  128  nissan             gas        std
# 90             1                  128  nissan          diesel        std
# 91             1                  128  nissan             gas        std
# 92             1                  122  nissan             gas        std
# 93             1                  103  nissan             gas        std
# 94             1                  128  nissan             gas        std
# 95             1                  128  nissan             gas        std
# 96             1                  122  nissan             gas        std
# 97             1                  103  nissan             gas        std
# 98             2                  168  nissan             gas        std
#
#    numPuertas estiloCarroceria ruedasMotrices ubicacionMotor  baseRuedas  ...  \
# 89        two            sedan            fwd          front        94.5  ...
# ...

# %% [markdown]
# <h3 style="color:#483d8b">1.3. Revisar los encabezados</h3>

# %%
dfAutos1.info() #Sirve para observar la informacion general
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   simbolizando          99 non-null     int64
#  1   perdidasNormalizadas  99 non-null     object
#  2   marca                 99 non-null     object
#  3   tipoCombustible       99 non-null     object
#  4   aspiracion            99 non-null     object
#  5   numPuertas            99 non-null     object
#  6   estiloCarroceria      99 non-null     object
#  7   ruedasMotrices        99 non-null     object
#  8   ubicacionMotor        99 non-null     object
#  9   baseRuedas            99 non-null     float64
#  10  longitud              99 non-null     float64
#  11  ancho                 99 non-null     float64
#  12  altura                99 non-null     float64
#  13  peso                  99 non-null     int64
#  14  tipoMotor             99 non-null     object
# ...
