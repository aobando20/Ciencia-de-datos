# %% [markdown]
# <center> <h1 style="color:#943F1D"> Precios de Venta de Bovinos Comercializados en Subastas </center></h1>
# <center> <h2 style="color:#943F1D">  Período 2007-2021 </h2> </center>
# <center> <h2 style="color:#943F1D">  Precio en colones por kilo en pie </h2> </center>
# <center> <h3 style="color:#943F1D"> Fuente: Federacion de Subastas Ganaderas </h3> </center>

# %%
import pandas as pd
import numpy as np
import matplotlib as mlpt
import matplotlib.pyplot as plt

# %%
archivo = "C:\\Users\CPU1\Desktop\Ciencia de datos\Precios Ganado CORFOGA\\Precios subasta3.xlsx"

dfsubasta = pd.read_excel(archivo, sheet_name='Precios de subasta')

# %%
dfsubasta.shape
# Out:
# (3348, 13)

# %%
dfsubasta.head()
# Out:
#   Unnamed: 0  \
# 0        Año
# 1       2007
# 2       2007
# 3       2007
# 4       2007
#
#   Precios de Venta de Bovinos Comercializados en Subastas, Período 2007-2012\n(Precio en colones por kilo en pie)\nFuente: FEDERACIÓN DE SUBASTAS GANADERAS  \
# 0                                                Mes
# 1                                              Enero
# 2                                              Enero
# 3                                              Enero
# 4                                              Enero
#
#   Unnamed: 2          Unnamed: 3      Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0     Género  Rango de Peso (kg)  Precio  (¢/kg)         NaN         NaN
# 1      Macho             000-100             737         NaN         NaN
# 2      Macho             101-150             746         NaN         NaN
# 3      Macho             151-200             750         NaN         NaN
# 4      Macho             201-250             740         NaN         NaN
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12
# 0         NaN         NaN         NaN          NaN          NaN          NaN
# 1         NaN         NaN         NaN          NaN          NaN          NaN
# 2         NaN         NaN         NaN          NaN          NaN          NaN
# 3         NaN         NaN         NaN          NaN          NaN          NaN
# 4         NaN         NaN         NaN          NaN          NaN          NaN

# %%
dfsubasta.drop(["Unnamed: 5","Unnamed: 6","Unnamed: 7","Unnamed: 8","Unnamed: 9","Unnamed: 10","Unnamed: 11","Unnamed: 12"], axis = 'columns', inplace=True)

# %%
dfsubasta
# Out:
#      Unnamed: 0  \
# 0           Año
# 1          2007
# 2          2007
# 3          2007
# 4          2007
# ...         ...
# 3343       2021
# 3344       2021
# 3345       2021
# 3346       2021
# 3347       2021
#
#      Precios de Venta de Bovinos Comercializados en Subastas, Período 2007-2012\n(Precio en colones por kilo en pie)\nFuente: FEDERACIÓN DE SUBASTAS GANADERAS  \
# 0                                                   Mes
# 1                                                 Enero
# 2                                                 Enero
# 3                                                 Enero
# 4                                                 Enero
# ...                                                 ...
# 3343                                         Septiembre
# 3344                                         Septiembre
# 3345                                         Septiembre
# 3346                                         Septiembre
# 3347                                         Septiembre
#
#      Unnamed: 2          Unnamed: 3      Unnamed: 4
# 0        Género  Rango de Peso (kg)  Precio  (¢/kg)
# 1         Macho             000-100             737
# 2         Macho             101-150             746
# 3         Macho             151-200             750
# 4         Macho             201-250             740
# ...         ...                 ...             ...
# 3343     Hembra             251-300     1194.039002
# 3344     Hembra             301-350     1208.697698
# 3345     Hembra             351-400     1202.911612
# 3346     Hembra             401-500     1206.598845
# 3347     Hembra          Más de 500     1217.593734
#
# [3348 rows x 5 columns]

# %%
dfsubasta.rename(columns={"Unnamed: 0":"Año","Precios de Venta de Bovinos Comercializados en Subastas, Período 2007-2012\n(Precio en colones por kilo en pie)\nFuente: FEDERACIÓN DE SUBASTAS GANADERAS":"Mes","Unnamed: 2":"Genero","Unnamed: 3":"Rango de peso","Unnamed: 4":"Precio kg/¢"},inplace=True)

# %%
dfsubasta
# Out:
#        Año         Mes  Genero       Rango de peso     Precio kg/¢
# 0      Año         Mes  Género  Rango de Peso (kg)  Precio  (¢/kg)
# 1     2007       Enero   Macho             000-100             737
# 2     2007       Enero   Macho             101-150             746
# 3     2007       Enero   Macho             151-200             750
# 4     2007       Enero   Macho             201-250             740
# ...    ...         ...     ...                 ...             ...
# 3343  2021  Septiembre  Hembra             251-300     1194.039002
# 3344  2021  Septiembre  Hembra             301-350     1208.697698
# 3345  2021  Septiembre  Hembra             351-400     1202.911612
# 3346  2021  Septiembre  Hembra             401-500     1206.598845
# 3347  2021  Septiembre  Hembra          Más de 500     1217.593734
#
# [3348 rows x 5 columns]

# %%
dfsubasta.dtypes
# Out:
# Año              object
# Mes              object
# Genero           object
# Rango de peso    object
# Precio kg/¢      object
# dtype: object

# %%
dfsubasta = dfsubasta.apply(lambda x: x.replace('.', ',')) # Para  reemplazar los valores con punto por una coma

# %%
dfsubasta.drop([0],axis=0, inplace=True) # Para eliminar la fila 0 con encabezados

# %%
dfsubasta
# Out:
#        Año         Mes  Genero Rango de peso  Precio kg/¢
# 1     2007       Enero   Macho       000-100          737
# 2     2007       Enero   Macho       101-150          746
# 3     2007       Enero   Macho       151-200          750
# 4     2007       Enero   Macho       201-250          740
# 5     2007       Enero   Macho       251-300          704
# ...    ...         ...     ...           ...          ...
# 3343  2021  Septiembre  Hembra       251-300  1194.039002
# 3344  2021  Septiembre  Hembra       301-350  1208.697698
# 3345  2021  Septiembre  Hembra       351-400  1202.911612
# 3346  2021  Septiembre  Hembra       401-500  1206.598845
# 3347  2021  Septiembre  Hembra    Más de 500  1217.593734
#
# [3347 rows x 5 columns]

# %%
dfsubasta["Precio kg/¢"]=dfsubasta["Precio kg/¢"].astype("float")

# %%
dfsubasta
# Out:
#        Año         Mes  Genero Rango de peso  Precio kg/¢
# 1     2007       Enero   Macho       000-100   737.000000
# 2     2007       Enero   Macho       101-150   746.000000
# 3     2007       Enero   Macho       151-200   750.000000
# 4     2007       Enero   Macho       201-250   740.000000
# 5     2007       Enero   Macho       251-300   704.000000
# ...    ...         ...     ...           ...          ...
# 3343  2021  Septiembre  Hembra       251-300  1194.039002
# 3344  2021  Septiembre  Hembra       301-350  1208.697698
# 3345  2021  Septiembre  Hembra       351-400  1202.911612
# 3346  2021  Septiembre  Hembra       401-500  1206.598845
# 3347  2021  Septiembre  Hembra    Más de 500  1217.593734
#
# [3347 rows x 5 columns]

# %% [markdown]
# <h3 style="color:#88BECA"> Cual es el mayor precio pagado en el 2021 en la subasta y a cual rango de peso corresponde? </h3>

# %%
precios2021=dfsubasta.loc[dfsubasta["Año"]==2021,["Año","Mes","Rango de peso","Precio kg/¢"]]
precios2021.head()
# Out:
#        Año    Mes Rango de peso  Precio kg/¢
# 3186  2021  Enero       000-100   951.677216
# 3187  2021  Enero       101-150  1307.679251
# 3188  2021  Enero       151-200  1367.269573
# 3189  2021  Enero       201-250  1319.963537
# 3190  2021  Enero       251-300  1203.711488

# %%
precios2021.max()
# Out:
# Año                     2021
# Mes               Septiembre
# Rango de peso     Más de 500
# Precio kg/¢      1622.263498
# dtype: object

# %% [markdown]
# <h3 style="color:#88BECA"> Cual es el menor precio pagado en el 2021 en la subasta y a cual rango de peso corresponde? </h3>

# %%
precios2021.min()
# Out:
# Año                    2021
# Mes                   Abril
# Rango de peso       000-100
# Precio kg/¢      951.677216
# dtype: object

# %% [markdown]
# <h3 style="color:#88BECA"> Cual es el precio promedio pagado en la subasta? </h3>

# %%
precios2021.mean()
# Out:
# Año            2021.000000
# Precio kg/¢    1263.865799
# dtype: float64

# %% [markdown]
# <h3 style="color:#88BECA"> Hay alguna variacion significativa del precio con respecto al mes? </h3>

# %%
mes2021=precios2021.groupby(precios2021["Mes"]).mean()
mes2021
# Out:
#             Precio kg/¢
# Mes
# Abril       1219.703795
# Agosto      1346.455073
# Enero       1120.205425
# Febrero     1150.870848
# Julio       1327.275369
# Junio       1344.381766
# Marzo       1182.672686
# Mayo        1323.517814
# Septiembre  1359.709413

# %%
new_order1 = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre']

mes2021= mes2021.reindex(new_order1, axis=0)
mes2021
# Out:
#             Precio kg/¢
# Mes
# Enero       1120.205425
# Febrero     1150.870848
# Marzo       1182.672686
# Abril       1219.703795
# Mayo        1323.517814
# Junio       1344.381766
# Julio       1327.275369
# Agosto      1346.455073
# Septiembre  1359.709413

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting

x = ["Enero","Febrero","Marzo","Abril","Mayo","Junio","Julio","Agosto","Septiembre"]

y = mes2021= mes2021.reindex(new_order1, axis=0)

fig, ax = plt.subplots()
ax.plot(x, y)

ax.set(xlabel='Meses', ylabel='Precio kg/¢',
       title='Precios de subasta por mes Año 2021')
ax.grid()

fig.set_figheight(5)
fig.set_figwidth(10)


fig.savefig("test.png")
plt.show()

# %% [markdown]
# <h3 style="color:#88BECA"> Cual es el precio promedio para toros de 400 a 500 kg? </h3>

# %%
pesos2021=precios2021[precios2021['Rango de peso'].str.contains('401-500') == True]
pesos2021.head()
# Out:
#        Año      Mes Rango de peso  Precio kg/¢
# 3193  2021    Enero       401-500  1191.581371
# 3202  2021    Enero       401-500   970.376044
# 3211  2021  Febrero       401-500  1215.765132
# 3220  2021  Febrero       401-500  1007.392480
# 3229  2021    Marzo       401-500  1243.137409

# %%
pesos2021.groupby("Rango de peso").mean()
# Out:
#                Precio kg/¢
# Rango de peso
# 401-500        1205.073043

# %% [markdown]
# <h3 style="color:#88BECA"> Cual es el precio promedio para toros de mas de 500 kg? </h3>

# %%
pesos20212=precios2021[precios2021['Rango de peso'].str.contains('Más de 500') == True]
pesos2021.head()
# Out:
#        Año      Mes Rango de peso  Precio kg/¢
# 3193  2021    Enero       401-500  1191.581371
# 3202  2021    Enero       401-500   970.376044
# 3211  2021  Febrero       401-500  1215.765132
# 3220  2021  Febrero       401-500  1007.392480
# 3229  2021    Marzo       401-500  1243.137409

# %%
pesos20212.groupby("Rango de peso").mean()
# Out:
#                Precio kg/¢
# Rango de peso
# Más de 500     1229.905872

# %% [markdown]
# <h3 style="color:#88BECA"> Cual es la relacion de precio con respecto al genero? </h3>

# %%
dfsubasta.head(5)
# Out:
#     Año    Mes Genero Rango de peso  Precio kg/¢
# 1  2007  Enero  Macho       000-100        737.0
# 2  2007  Enero  Macho       101-150        746.0
# 3  2007  Enero  Macho       151-200        750.0
# 4  2007  Enero  Macho       201-250        740.0
# 5  2007  Enero  Macho       251-300        704.0

# %%
genero=pd.pivot_table(dfsubasta, values='Precio kg/¢', index=['Año'],
                    columns=['Genero'], aggfunc={'Precio kg/¢':np.mean})
genero
# Out:
# Genero       Hembra        Macho
# Año
# 2007     607.481481   714.704545
# 2008     546.731481   643.441667
# 2009     438.166667   545.375000
# 2010     453.444444   555.420168
# 2011     534.564815   651.907563
# 2012     718.198430   859.097137
# 2013     770.837293   936.154227
# 2014     844.520275   990.475858
# 2015    1083.550594  1260.648320
# 2016    1069.646657  1250.429203
# 2017     952.375408  1135.573957
# 2018     838.988106  1048.178413
# 2019     786.389139  1007.650822
# 2020     941.142768  1152.172793
# 2021    1157.363605  1370.367992

# %%
genero.query("Año==[2021]")
# Out:
# Genero       Hembra        Macho
# Año
# 2021    1157.363605  1370.367992

# %% [markdown]
# <center> <h1 style="color:#943F1D"> Precios Canal Semanal de Machos y Hembras en Plantas de Cosecha Nacionales </center></h1>
# <center> <h2 style="color:#943F1D">  Período 2002-2021 </h2> </center>
# <center> <h2 style="color:#943F1D">  Precios en Colones Corrientes por Kilogramo  </h2> </center>
# <center> <h3 style="color:#943F1D"> Fuente: Plantas de Cosecha </h3> </center>

# %%
archivo = "C:\\Users\CPU1\Desktop\Ciencia de datos\Precios Ganado CORFOGA\\Precios canal2.xlsx"

dfcanal = pd.read_excel(archivo, sheet_name='Precios Nacionales')

# %%
dfcanal.shape
# Out:
# (7190, 12)

# %%
dfcanal.head()
# Out:
#    Semana   Año    Mes      Desde      Hasta Planta de cosecha  Género  \
# 0       1  2002  Enero 2001-12-31 2002-01-06       Montecillos  Hembra
# 1       1  2002  Enero 2001-12-31 2002-01-06          El Arreo  Hembra
# 2       1  2002  Enero 2001-12-31 2002-01-06         Del Valle  Hembra
# 3       1  2002  Enero 2001-12-31 2002-01-06       Montecillos   Macho
# 4       1  2002  Enero 2001-12-31 2002-01-06          El Arreo   Macho
#
#   Precio (¢/kg)  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 0           690         NaN         NaN          NaN          NaN
# 1           690         NaN         NaN          NaN          NaN
# 2           695         NaN         NaN          NaN          NaN
# 3           740         NaN         NaN          NaN          NaN
# 4           725         NaN         NaN          NaN          NaN

# %%
dfcanal.dropna(axis=1)
# Out:
#       Semana   Año      Mes      Desde      Hasta Planta de cosecha  Género
# 0          1  2002    Enero 2001-12-31 2002-01-06       Montecillos  Hembra
# 1          1  2002    Enero 2001-12-31 2002-01-06          El Arreo  Hembra
# 2          1  2002    Enero 2001-12-31 2002-01-06         Del Valle  Hembra
# 3          1  2002    Enero 2001-12-31 2002-01-06       Montecillos   Macho
# 4          1  2002    Enero 2001-12-31 2002-01-06          El Arreo   Macho
# ...      ...   ...      ...        ...        ...               ...     ...
# 7185       4  2021  Octubre 2021-10-25 2021-10-31              GICO  Hembra
# 7186       4  2021  Octubre 2021-10-25 2021-10-31       Montecillos   Macho
# 7187       4  2021  Octubre 2021-10-25 2021-10-31          El Arreo   Macho
# 7188       4  2021  Octubre 2021-10-25 2021-10-31         Del Valle   Macho
# 7189       4  2021  Octubre 2021-10-25 2021-10-31              GICO   Macho
#
# [7190 rows x 7 columns]

# %%
dfcanal
# Out:
#       Semana   Año      Mes      Desde      Hasta Planta de cosecha  Género  \
# 0          1  2002    Enero 2001-12-31 2002-01-06       Montecillos  Hembra
# 1          1  2002    Enero 2001-12-31 2002-01-06          El Arreo  Hembra
# 2          1  2002    Enero 2001-12-31 2002-01-06         Del Valle  Hembra
# 3          1  2002    Enero 2001-12-31 2002-01-06       Montecillos   Macho
# 4          1  2002    Enero 2001-12-31 2002-01-06          El Arreo   Macho
# ...      ...   ...      ...        ...        ...               ...     ...
# 7185       4  2021  Octubre 2021-10-25 2021-10-31              GICO  Hembra
# 7186       4  2021  Octubre 2021-10-25 2021-10-31       Montecillos   Macho
# 7187       4  2021  Octubre 2021-10-25 2021-10-31          El Arreo   Macho
# 7188       4  2021  Octubre 2021-10-25 2021-10-31         Del Valle   Macho
# 7189       4  2021  Octubre 2021-10-25 2021-10-31              GICO   Macho
#
#      Precio (¢/kg)
# 0              690
# 1              690
# 2              695
# 3              740
# 4              725
# ...            ...
# 7185          2350
# 7186          2800
# 7187          2750
# 7188          2860
# 7189          2750
#
# [7190 rows x 8 columns]

# %%
dfcanal.dtypes
# Out:
# Semana                        int64
# Año                           int64
# Mes                          object
# Desde                datetime64[ns]
# Hasta                datetime64[ns]
# Planta de cosecha            object
# Género                       object
# Precio (¢/kg)                object
# dtype: object

# %%
valoresperdidos=dfcanal.isnull()
for column in valoresperdidos.columns.values.tolist():
    print(column)
    print(valoresperdidos[column].value_counts())
    print(" ")
# Out:
# Semana
# False    7190
# Name: Semana, dtype: int64
#
# Año
# False    7190
# Name: Año, dtype: int64
#
# Mes
# False    7190
# Name: Mes, dtype: int64
#
# Desde
# False    7190
# Name: Desde, dtype: int64
#
# Hasta
# False    7190
# Name: Hasta, dtype: int64
#
# Planta de cosecha
# False    7190
# Name: Planta de cosecha, dtype: int64
#
# Género
# False    7190
# Name: Género, dtype: int64
#
# Precio (¢/kg)
# False    7132
# True       58
# Name: Precio (¢/kg), dtype: int64

# %%
dfcanal["Precio (¢/kg)"].replace("ND",0,inplace=True)
dfcanal.head()
# Out:
#    Semana   Año    Mes      Desde      Hasta Planta de cosecha  Género  \
# 0       1  2002  Enero 2001-12-31 2002-01-06       Montecillos  Hembra
# 1       1  2002  Enero 2001-12-31 2002-01-06          El Arreo  Hembra
# 2       1  2002  Enero 2001-12-31 2002-01-06         Del Valle  Hembra
# 3       1  2002  Enero 2001-12-31 2002-01-06       Montecillos   Macho
# 4       1  2002  Enero 2001-12-31 2002-01-06          El Arreo   Macho
#
#    Precio (¢/kg)
# 0          690.0
# 1          690.0
# 2          695.0
# 3          740.0
# 4          725.0

# %%
dfcanal = dfcanal.apply(lambda x: x.replace('.', ',')) # Para  reemplazar los valores con punto por una coma

# %%
dfcanal.dtypes
# Out:
# Semana                        int64
# Año                           int64
# Mes                          object
# Desde                datetime64[ns]
# Hasta                datetime64[ns]
# Planta de cosecha            object
# Género                       object
# Precio (¢/kg)               float64
# dtype: object

# %% [markdown]
# <h3 style="color:#88BECA"> Cual es el mayor precio pagado en el 2021 en canal? </h3>

# %%
canal2021=dfcanal.loc[dfcanal["Año"]==2021,["Año","Mes","Planta de cosecha","Género","Precio (¢/kg)"]]

# %%
canal2021.max()
# Out:
# Año                         2021
# Mes                   Septiembre
# Planta de cosecha    Montecillos
# Género                     Macho
# Precio (¢/kg)             2860.0
# dtype: object

# %% [markdown]
# <h3 style="color:#88BECA"> Cual es el menor precio pagado en el 2021 en canal? </h3>

# %%
canal2021.min()
# Out:
# Año                       2021
# Mes                      Abril
# Planta de cosecha    Del Valle
# Género                  Hembra
# Precio (¢/kg)           1500.0
# dtype: object

# %% [markdown]
# <h3 style="color:#88BECA"> Cual es el precio promedio pagado en el 2021 en canal? </h3>

# %%
canal2021.mean()
# Out:
# Año              2021.000000
# Precio (¢/kg)    2308.194079
# dtype: float64

# %% [markdown]
# <h3 style="color:#88BECA"> Hay alguna variacion significativa del precio con respecto al mes? </h3>

# %%
canal2021
# Out:
#        Año      Mes Planta de cosecha  Género  Precio (¢/kg)
# 6886  2021    Enero       Montecillos  Hembra         1907.0
# 6887  2021    Enero          El Arreo  Hembra         1900.0
# 6888  2021    Enero              GICO  Hembra         1985.0
# 6889  2021    Enero       Montecillos   Macho         2050.0
# 6890  2021    Enero          El Arreo   Macho         2090.0
# ...    ...      ...               ...     ...            ...
# 7185  2021  Octubre              GICO  Hembra         2350.0
# 7186  2021  Octubre       Montecillos   Macho         2800.0
# 7187  2021  Octubre          El Arreo   Macho         2750.0
# 7188  2021  Octubre         Del Valle   Macho         2860.0
# 7189  2021  Octubre              GICO   Macho         2750.0
#
# [304 rows x 5 columns]

# %%
meses2021=canal2021.groupby(canal2021["Mes"]).mean()
meses2021=meses2021.iloc[:,1:2]

# %%
new_order = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre']

meses2021= meses2021.reindex(new_order, axis=0)
meses2021
# Out:
#             Precio (¢/kg)
# Mes
# Enero         2047.071429
# Febrero       2061.000000
# Marzo         2171.785714
# Abril         2216.714286
# Mayo          2237.931034
# Junio         2252.333333
# Julio         2300.000000
# Agosto        2511.607143
# Septiembre    2591.000000
# Octubre       2653.214286

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting

x = ["Enero","Febrero","Marzo","Abril","Mayo","Junio","Julio","Agosto","Septiembre","Octubre"]

y = meses2021= meses2021.reindex(new_order, axis=0)
fig, ax = plt.subplots()
ax.plot(x, y)

ax.set(xlabel='Meses', ylabel='Precio kg/¢',
       title='Precios de canal por mes')
ax.grid()

fig.set_figheight(5)
fig.set_figwidth(10)
    

fig.savefig("test.png")
plt.show()

# %% [markdown]
# <h3 style="color:#88BECA"> Cual es el precio de venta por planta? </h3>

# %%
planta2021=canal2021.groupby("Planta de cosecha").mean()
planta2021=planta2021.iloc[:,1:2]
planta2021
# Out:
#                    Precio (¢/kg)
# Planta de cosecha
# Del Valle            2400.217391
# El Arreo             2297.093023
# GICO                 2247.325581
# Montecillos          2330.941860

# %%
import matplotlib.pyplot as plt
 
## Declaramos valores para el eje x
eje_x = ['Del Valle', 'El Arreo', 'Gico', 'Montecillos']
 
## Declaramos valores para el eje y
eje_y = [2440.21,2297.09,2247.32,2330.94]
 
## Creamos Gráfica
plt.bar(eje_x, eje_y)
 
## Legenda en el eje y
plt.ylabel('Precio por Kg')
 
## Legenda en el eje x
plt.xlabel('Planta de cosecha')
 
## Título de Gráfica
plt.title('Precios de venta por planta de cosecha 2021')


# Para poner etiqueta de grafico
for x,y in enumerate(eje_y):
    plt.text(x,y+300,'%s' %round(y,1),ha='center')

    
# Para especificar rango del grafico(eje y)
    plt.ylim([500,3000])

## Mostramos Gráfica
plt.show()

# %% [markdown]
# <h3 style="color:#88BECA"> Cual es la relacion de precio con respecto al genero? </h3>

# %%
dfcanal.head(2)
# Out:
#       Semana   Año    Mes      Desde      Hasta Planta de cosecha  Género  \
# 0          1  2002  Enero 2001-12-31 2002-01-06       Montecillos  Hembra
# 2433       2  2010  Enero 2010-01-11 2010-01-17       Montecillos   Macho
#
#       Precio (¢/kg)
# 0             690.0
# 2433         1260.0

# %%
genero1=pd.pivot_table(dfcanal, values='Precio (¢/kg)', index=['Año'],
                    columns=['Género'], aggfunc={'Precio (¢/kg)':np.mean})
genero1
# Out:
# Género       Hembra        Macho
# Año
# 2002     684.341085   725.325581
# 2003     689.687500   727.326389
# 2004     762.564103   809.724359
# 2005     926.820513   988.076923
# 2006    1138.108974  1235.448718
# 2007    1200.192308  1293.269231
# 2008    1222.179487  1324.012821
# 2009    1150.157233  1307.949686
# 2010    1069.581152  1269.790576
# 2011    1218.004808  1410.600962
# 2012    1531.033654  1722.235577
# 2013    1532.222222  1680.434783
# 2014    1828.102564  1959.230769
# 2015    2181.619792  2313.854167
# 2016    1999.093137  2133.161765
# 2017    1846.155660  1997.452830
# 2018    1702.860577  1871.274038
# 2019    1637.278846  1857.158654
# 2020    1801.326087  2075.570377
# 2021    2171.977273  2412.732558

# %%
genero1.query('Año==[2021]')
# Out:
# Género       Hembra        Macho
# Año
# 2021    2171.977273  2412.732558

# %% [markdown]
# <center> <h1 style="color:#943F1D"> Ventas Ganado Pabeber S.A.</center></h1>
# <center> <h2 style="color:#943F1D">  Período 2018-2021 </h2> </center>
# <center> <h3 style="color:#943F1D"> Fuente: Registros de ventas Pabeber S.A </h3> </center>

# %%
archivo = "C:\\Users\CPU1\Desktop\Ciencia de datos\\Ventas ganado Pabeber2.xlsx"

dfpabeber = pd.read_excel(archivo, sheet_name='Lista Ventas')

# %%
dfpabeber.head(3)
# Out:
#    Unnamed: 0  Arete  # Animal      Fecha  Liquidacion Subasta  Cheque   Sexo  \
# 0         NaN    121       4.0 2021-11-07     151101.0     NaN     NaN  Macho
# 1         NaN    120      12.0 2021-11-07     151101.0     NaN     NaN  Macho
# 2         NaN    119      16.0 2021-11-07     151101.0     NaN     NaN  Macho
#
#     Color Per    Nombre de Comprador  No. Cedula  Peso Finca  Peso Venta  \
# 0  Blanco   S  Coopemontecillos R.L.  3004075581       367.0       660.0
# 1  Blanco   S  Coopemontecillos R.L.  3004075581       323.5       602.0
# 2  Blanco   S  Coopemontecillos R.L.  3004075581       306.5       572.0
#
#    Precio Unitario      Total  Unnamed: 16  Cantidad de ventas  Unnamed: 18  \
# 0           2676.3  982202.10          NaN                 NaN          NaN
# 1           2676.3  865783.05          NaN                 NaN          NaN
# 2           2676.3  820285.95          NaN                 NaN          NaN
#
#    368
# 0  NaN
# 1  NaN
# 2  NaN

# %%
dfpabeber.drop(["Unnamed: 0","Liquidacion","Subasta","Cheque","Sexo","Color","Per","No. Cedula","No. Cedula","Unnamed: 16","Cantidad de ventas","Unnamed: 18",368], axis = 'columns', inplace=True)

# %%
dfpabeber
# Out:
#      Arete  # Animal      Fecha    Nombre de Comprador  Peso Finca  \
# 0      121       4.0 2021-11-07  Coopemontecillos R.L.       367.0
# 1      120      12.0 2021-11-07  Coopemontecillos R.L.       323.5
# 2      119      16.0 2021-11-07  Coopemontecillos R.L.       306.5
# 3      118       9.0 2021-11-07  Coopemontecillos R.L.       333.0
# 4      117      13.0 2021-11-07  Coopemontecillos R.L.       319.5
# ..     ...       ...        ...                    ...         ...
# 363    751     556.0 2018-08-09                    NaN       613.0
# 364    745     562.0 2018-08-09                    NaN       586.0
# 365    738     559.0 2018-08-09                    NaN       523.0
# 366    727     554.0 2018-08-09                    NaN       569.0
# 367    724     558.0 2018-08-09                    NaN       579.0
#
#      Peso Venta  Precio Unitario      Total
# 0         660.0           2676.3  982202.10
# 1         602.0           2676.3  865783.05
# 2         572.0           2676.3  820285.95
# 3         610.0           2676.3  891207.90
# 4         598.0           2676.3  855077.85
# ..          ...              ...        ...
# 363       635.0           1240.0  760120.00
# 364       619.0           1205.0  706130.00
# 365       546.0           1220.0  639280.00
# 366       591.0           1235.0  702715.00
# 367       589.0           1225.0  709275.00
#
# [368 rows x 8 columns]

# %%
dfpabeber.dtypes
# Out:
# Arete                           int64
# # Animal                      float64
# Fecha                  datetime64[ns]
# Nombre de Comprador            object
# Peso Finca                    float64
# Peso Venta                    float64
# Precio Unitario               float64
# Total                         float64
# dtype: object

# %%
dfpabeber
# Out:
#      Arete  # Animal      Fecha    Nombre de Comprador  Peso Finca  \
# 0      121       4.0 2021-11-07  Coopemontecillos R.L.       367.0
# 1      120      12.0 2021-11-07  Coopemontecillos R.L.       323.5
# 2      119      16.0 2021-11-07  Coopemontecillos R.L.       306.5
# 3      118       9.0 2021-11-07  Coopemontecillos R.L.       333.0
# 4      117      13.0 2021-11-07  Coopemontecillos R.L.       319.5
# ..     ...       ...        ...                    ...         ...
# 363    751     556.0 2018-08-09                    NaN       613.0
# 364    745     562.0 2018-08-09                    NaN       586.0
# 365    738     559.0 2018-08-09                    NaN       523.0
# 366    727     554.0 2018-08-09                    NaN       569.0
# 367    724     558.0 2018-08-09                    NaN       579.0
#
#      Peso Venta  Precio Unitario      Total
# 0         660.0           2676.3  982202.10
# 1         602.0           2676.3  865783.05
# 2         572.0           2676.3  820285.95
# 3         610.0           2676.3  891207.90
# 4         598.0           2676.3  855077.85
# ..          ...              ...        ...
# 363       635.0           1240.0  760120.00
# 364       619.0           1205.0  706130.00
# 365       546.0           1220.0  639280.00
# 366       591.0           1235.0  702715.00
# 367       589.0           1225.0  709275.00
#
# [368 rows x 8 columns]

# %%
dfpabeber["Año"]= pd.DatetimeIndex(dfpabeber['Fecha']).year
dfpabeber["Mes"]= pd.DatetimeIndex(dfpabeber['Fecha']).month
dfpabeber
# Out:
#      Arete  # Animal      Fecha   Año  Mes    Nombre de Comprador  Peso Finca  \
# 0      121       4.0 2021-11-07  2021   11  Coopemontecillos R.L.       367.0
# 1      120      12.0 2021-11-07  2021   11  Coopemontecillos R.L.       323.5
# 2      119      16.0 2021-11-07  2021   11  Coopemontecillos R.L.       306.5
# 3      118       9.0 2021-11-07  2021   11  Coopemontecillos R.L.       333.0
# 4      117      13.0 2021-11-07  2021   11  Coopemontecillos R.L.       319.5
# ..     ...       ...        ...   ...  ...                    ...         ...
# 363    751     556.0 2018-08-09  2018    8                    NaN       613.0
# 364    745     562.0 2018-08-09  2018    8                    NaN       586.0
# 365    738     559.0 2018-08-09  2018    8                    NaN       523.0
# 366    727     554.0 2018-08-09  2018    8                    NaN       569.0
# 367    724     558.0 2018-08-09  2018    8                    NaN       579.0
#
#      Peso Venta  Precio Unitario      Total
# 0         660.0           2676.3  982202.10
# 1         602.0           2676.3  865783.05
# 2         572.0           2676.3  820285.95
# 3         610.0           2676.3  891207.90
# 4         598.0           2676.3  855077.85
# ..          ...              ...        ...
# 363       635.0           1240.0  760120.00
# 364       619.0           1205.0  706130.00
# 365       546.0           1220.0  639280.00
# 366       591.0           1235.0  702715.00
# 367       589.0           1225.0  709275.00
#
# [368 rows x 10 columns]

# %%
dfpabeber = dfpabeber.reindex(columns=['Arete','# Animal','Fecha','Año','Mes','Nombre de Comprador','Peso Finca','Peso Venta','Precio Unitario','Total'])
dfpabeber
# Out:
#      Arete  # Animal      Fecha   Año  Mes    Nombre de Comprador  Peso Finca  \
# 0      121       4.0 2021-11-07  2021   11  Coopemontecillos R.L.       367.0
# 1      120      12.0 2021-11-07  2021   11  Coopemontecillos R.L.       323.5
# 2      119      16.0 2021-11-07  2021   11  Coopemontecillos R.L.       306.5
# 3      118       9.0 2021-11-07  2021   11  Coopemontecillos R.L.       333.0
# 4      117      13.0 2021-11-07  2021   11  Coopemontecillos R.L.       319.5
# ..     ...       ...        ...   ...  ...                    ...         ...
# 363    751     556.0 2018-08-09  2018    8                    NaN       613.0
# 364    745     562.0 2018-08-09  2018    8                    NaN       586.0
# 365    738     559.0 2018-08-09  2018    8                    NaN       523.0
# 366    727     554.0 2018-08-09  2018    8                    NaN       569.0
# 367    724     558.0 2018-08-09  2018    8                    NaN       579.0
#
#      Peso Venta  Precio Unitario      Total
# 0         660.0           2676.3  982202.10
# 1         602.0           2676.3  865783.05
# 2         572.0           2676.3  820285.95
# 3         610.0           2676.3  891207.90
# 4         598.0           2676.3  855077.85
# ..          ...              ...        ...
# 363       635.0           1240.0  760120.00
# 364       619.0           1205.0  706130.00
# 365       546.0           1220.0  639280.00
# 366       591.0           1235.0  702715.00
# 367       589.0           1225.0  709275.00
#
# [368 rows x 10 columns]

# %% [markdown]
# <h3 style="color:#88BECA"> Cual es el precio maximo de venta en el año 2021? </h3>

# %%
añopabeber=dfpabeber.loc[dfpabeber["Año"]==2021,['Arete','# Animal','Fecha','Año','Mes','Nombre de Comprador','Peso Finca','Peso Venta','Precio Unitario','Total']]
añopabeber
# Out:
#     Arete  # Animal      Fecha   Año  Mes    Nombre de Comprador  Peso Finca  \
# 0     121       4.0 2021-11-07  2021   11  Coopemontecillos R.L.       367.0
# 1     120      12.0 2021-11-07  2021   11  Coopemontecillos R.L.       323.5
# 2     119      16.0 2021-11-07  2021   11  Coopemontecillos R.L.       306.5
# 3     118       9.0 2021-11-07  2021   11  Coopemontecillos R.L.       333.0
# 4     117      13.0 2021-11-07  2021   11  Coopemontecillos R.L.       319.5
# ..    ...       ...        ...   ...  ...                    ...         ...
# 77     89      89.0 2021-02-20  2021    2  Coopemontecillos R.L.       320.5
# 78     83      83.0 2021-02-20  2021    2  Coopemontecillos R.L.       347.5
# 79     80      80.0 2021-02-20  2021    2  Coopemontecillos R.L.       356.0
# 80     70      70.0 2021-02-20  2021    2  Coopemontecillos R.L.       351.0
# 81      9       9.0 2021-02-20  2021    2  Coopemontecillos R.L.       287.0
#
#     Peso Venta  Precio Unitario      Total
# 0        660.0           2676.3  982202.10
# 1        602.0           2676.3  865783.05
# 2        572.0           2676.3  820285.95
# 3        610.0           2676.3  891207.90
# 4        598.0           2676.3  855077.85
# ..         ...              ...        ...
# 77       597.0           2250.2  721189.10
# 78       623.0           2250.2  781944.50
# 79       669.0           2250.2  801071.20
# 80       659.0           2250.2  789820.20
# 81       568.0           2250.2  645807.40
#
# [82 rows x 10 columns]

# %%
añopabeber.max()
# Out:
# Arete                              999
# # Animal                         999.0
# Fecha              2021-11-07 00:00:00
# Año                               2021
# Mes                                 11
# Peso Finca                       464.0
# Peso Venta                       728.0
# Precio Unitario                 2676.3
# Total                       1055800.35
# dtype: object

# %% [markdown]
# <h3 style="color:#88BECA"> Cual es precio minimo de venta? </h3>

# %%
añopabeber.min()
# Out:
# Arete                                1
# # Animal                           1.0
# Fecha              2021-02-20 00:00:00
# Año                               2021
# Mes                                  2
# Peso Finca                       217.0
# Peso Venta                       217.0
# Precio Unitario                 1320.0
# Total                         390600.0
# dtype: object

# %% [markdown]
# <h3 style="color:#88BECA"> Cual es precio  promedio de venta el año 2021? </h3>

# %%
añopabeber.mean()
# Out:
# <ipython-input-221-1c2050d34be5>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   añopabeber.mean()
# Arete                 170.146341
# # Animal              147.719512
# Año                  2021.000000
# Mes                     6.658537
# Peso Finca            329.648148
# Peso Venta            603.414634
# Precio Unitario      2351.640741
# Total              772628.930488
# dtype: float64
